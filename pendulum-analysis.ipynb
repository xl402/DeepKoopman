# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import imageio
from IPython.display import Image

from helper_fn import *
plt.rcParams.update({'font.size': 22})
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Analysis of LREN Architecture

# %%
MODEL_NAME = "model-denis-50-1579628611"
ROOT_DIR = "logs/denis_pendulum"
FIG_DIR = os.path.join(ROOT_DIR, "figures/{}".format(MODEL_NAME))
DIST_DIR = os.path.join(ROOT_DIR, "dists/{}".format(MODEL_NAME))

model_dir = os.path.join(ROOT_DIR+'models', MODEL_NAME)
log_dir = os.path.join(ROOT_DIR, 'logs.csv')

df = load_df(log_dir, False)
model_df = df.loc[df['model_name'] == MODEL_NAME]
#model_df = model_df.tail(n=3800)
#model_df = model_df.tail(n=1900)
model_df.head()
# Out:
# Loading logs from logs/denis_pendulum/logs.csv
#                   model_name  epoch  train_loss  val_loss  train_state_mse  \
# 0  model-denis-50-1579628611      0    1.403482  1.335381         1.400109
# 1  model-denis-50-1579628611      0    1.246324  1.335001         1.243232
# 2  model-denis-50-1579628611      0    1.332167  1.334633         1.329084
# 3  model-denis-50-1579628611      0    1.328163  1.334276         1.325161
# 4  model-denis-50-1579628611      0    1.378064  1.333921         1.375139
#
#    val_state_mse  train_latent_mse  val_latent_mse  train_state_inf  \
# 0       1.332199          0.001226        0.001096         2.147512
# 1       1.331923          0.001085        0.000993         2.007218
# 2       1.331646          0.000984        0.000902         2.098752
# 3       1.331368          0.000903        0.000823         2.099791
# 4       1.331083          0.000837        0.000753         2.087827
#
#    val_state_inf
# 0       2.086408
# 1       2.085942
# ...

# %%
plot_losses(model_df)

# %% [raw]
# gif_dir = make_gif(FIG_DIR, ROOT_DIR, MODEL_NAME, ext='trj')
# Image(filename=gif_dir)

# %%
FIG_DIR
# Out:
# 'logs/lren_pendulum/figures/model-50-1579270713'

# %% [raw]
# gif_dir = make_gif(DIST_DIR, ROOT_DIR, MODEL_NAME, max_len=-1, t=2, ext='dist')
# Image(filename=gif_dir)

# %% [markdown]
# ## Analysis of DENIS Architecture

# %%
MODEL_NAME = "model-denis-50-1579649827"
ROOT_DIR = "logs/denis_pendulum"
FIG_DIR = os.path.join(ROOT_DIR, "figures/{}".format(MODEL_NAME))
DIST_DIR = os.path.join(ROOT_DIR, "dists/{}".format(MODEL_NAME))

model_dir = os.path.join(ROOT_DIR+'models', MODEL_NAME)
log_dir = os.path.join(ROOT_DIR, 'logs.csv')

df = load_df(log_dir, False)
model_df = df.loc[df['model_name'] == MODEL_NAME]
#model_df = model_df.tail(n=3800)
#model_df = model_df.tail(n=1900)
model_df.head()
# Out:
# Loading logs from logs/denis_pendulum/logs.csv
#                       model_name  epoch  train_loss  val_loss  \
# 21200  model-denis-50-1579649827      0    1.405044  1.337096
# 21201  model-denis-50-1579649827      0    1.248175  1.336944
# 21202  model-denis-50-1579649827      0    1.334049  1.336793
# 21203  model-denis-50-1579649827      0    1.330703  1.336642
# 21204  model-denis-50-1579649827      0    1.380595  1.336491
#
#        train_state_mse  val_state_mse  train_latent_mse  val_latent_mse  \
# 21200         1.402248       1.334396          0.000652        0.000616
# 21201         1.245556       1.334274          0.000614        0.000586
# 21202         1.331365       1.334151          0.000586        0.000558
# 21203         1.328044       1.334027          0.000561        0.000531
# 21204         1.377973       1.333902          0.000535        0.000505
#
#        train_state_inf  val_state_inf
# 21200         2.144101       2.084299
# ...

# %%
plot_losses(model_df)

# %% [raw]
# gif_dir = make_gif(FIG_DIR, ROOT_DIR, MODEL_NAME, max_len=-1, t=10, ext='trj')
# Image(filename=gif_dir)

# %% [raw]
# gif_dir = make_gif(DIST_DIR, ROOT_DIR, MODEL_NAME, max_len=-1, t=5, ext='dist')
# Image(filename=gif_dir)
